# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# 👋 **¡Hola! Soy Dot, tu revisor de IA.**
#
# He completado la primera revisión de tu código. A continuación, encontrarás mis comentarios y sugerencias de mejora.
#
# **¿Qué debes hacer ahora?**
#
# 1. **Revisar:** Lee mis comentarios en el notebook más abajo.
# 2. **Decidir:**
# * **¿Estás de acuerdo con el feedback?** ¡Genial! Actualiza tu código según las sugerencias.
# * **¿No estás de acuerdo o crees que es un error?** ¡No hay problema! Puedes dejar tu código exactamente como está.
#
#
# 3. **Volver a enviar:** Envía tu proyecto de nuevo. **Tu próxima iteración será revisada por un experto humano**, independientemente de si hiciste cambios o no.
#
# -------------------------------------------------------------------------------------------------------------
# Mis comentarios están más abajo. **Te pido amablemente que no los muevas, modifiques ni elimines**.
#
# Verás mis comentarios resaltados en cuadros verdes, amarillos o rojos como estos:
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Correcto. Todo se ha hecho exitosamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Necesita corrección. El bloque requiere algunas correcciones.
# </div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # ¡Hola Oscar!
#
# Mi nombre es Sofia Arboleda, estaré ayudándote a revisar este proyecto para que quede en su mejor versión. Corregiré algunas imprecisiones de la review de Dot y te dejaré mis propias recomendaciones o felicitaciones.
#
# Un gusto acompañarte en este proceso, vamos a ello!
#
# ### Comentario General Iteración #2
#
# Quiero dejarte aqui la apreciacion general del proyecto para que sepas en lo que debes enfocarte y luego vas punto por punto revisando mis recomendaciones.
#
# Respecto a tu trabajo en esta segunda iteración, felicitarte porque has mostrado tus conocimientos de la mejor forma, utilizando los metodos correctamente, realizando filtros de forma sencilla y trabajando con los diferentes datasets para llegar a las respuestas de negocio que se buscaban en este proyecto. Solo quedan algunas recomendaciones de mejora que te servirán para mejorar tus entregas a futuro y corregir el desarrollo.
#
# Sigue aprendiendo bastante en este camino, excelente trabajo!
# </div>

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %%
# importar librerías
## Importaré la librería pandas como "pd" para luego usar pd.read_csv()
## para importar y leer los datos de los archuivos .csv asignándolos a variables
## con nombres descriptivos y fáciles de identificar; los archivos están separados
## por ";" en vez de la esperada ",", por lo que usaré el argumento "sep = ";""
## para obtener la base de datos separada correctamente en columnas.
## Luego mostraré lso datos con el comando "print()" y la información general del df
## usando el método info()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Tu plan del Paso 1 está escrito como comentarios dentro de una celda de código, por lo que no se leerá como parte del informe. Considera mover este plan a la celda de markdown dedicada **“Plan de solución”** para que quede claramente documentado y sea fácil de encontrar.
#
# </div>

# %%
# leer conjuntos de datos en los DataFrames
import pandas as pd
df_icorders = pd.read_csv("/datasets/instacart_orders.csv", sep=";")
df_products = pd.read_csv("/datasets/products.csv", sep=";")
df_order = pd.read_csv("/datasets/order_products.csv", sep=";")
df_aisles = pd.read_csv("/datasets/aisles.csv", sep=";")
df_departments = pd.read_csv("/datasets/departments.csv", sep=";")

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Al leer los CSVs, está bien que hayas configurado `sep=';'`. Como comprobación rápida (sanity check), considera confirmar si algún archivo incluye una columna extra sin nombre, tipo índice (index-like) (y solo entonces usar parámetros como `index_col` si hace falta). Mostrar `head()`/`info()` es una excelente manera de verificar que la importación coincide con la estructura del archivo original.
#
# </div>

# %%
# mostrar información del DataFrame
print(df_icorders.head())
print(df_icorders.info())
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# 2                     2.0
# 3                    10.0
# 4                    17.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
# ...

# %%
# mostrar información del DataFrame
print(df_products.head())
print(df_products.info())
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# ...

# %%
# mostrar información del DataFrame
print(df_order.head())
print(df_order.info())
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
# None

# %%
# mostrar información del DataFrame
print(df_aisles.head())
print(df_aisles.info())
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
# None

# %%
# mostrar información del DataFrame
print(df_departments.head())
print(df_departments.info())
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
# None

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
#
# Los datos estaban separados por ";" por lo que se usó el argumento "sep=";"" para separar las columnas correctamente. La mayoría de df tiene data types correspodientes al tipo de dato esperado para cada fila a excepción de filas como "add_to_cart_order" (en df_order) que es de tipo float y se esperaría que fuera integer al ser una secuencia del orden en que se agregaron los productos al carrito, también, para claridad de datos, se podría cambiar el tipo de dato de la columna "days_since_prior_oder" (de df_icorders) a integer para tener un número de días extacto en vez de algo como "1,5 días". Por otro lado, tenemos datos ausentes en las bases de datos df_icorders (columna "days_since_prior_order"), df_producst (columna "product_name") y df_icorders (columna "days_since_prior_order")

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Tus conclusiones del Paso 1 serían más sólidas si resumieran con precisión (1) qué columnas tienen valores faltantes (incluyendo `add_to_cart_order`, que es relevante más adelante) y (2) qué `dtypes` realmente necesitan cambios. Además, convertir `days_since_prior_order` a entero a menudo no es apropiado porque incluye NaNs y representa un intervalo numérico; mantenerlo como numérico (float con NaN) suele ser más útil para el análisis.
#
# </div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
#
# En este paso usaré métodos como info(), isna(), duplicated() y sum() para verificar los tipos de datos, verificar si hay valores ausentes y contar cuántos valores ausentes hay, con esta información podré llegar a conclusiones acerca de los datos y posibles causas de los datos ausentes y duplicados.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados
dups_order_id = df_icorders.duplicated().sum()
print(f"Hay {dups_order_id} filas duplicadas. Estos duplicados están el al columna 'order_id'")
print()
print(df_icorders[df_icorders.duplicated()])
# Out:
# Hay 15 filas duplicadas. Estos duplicados están el al columna 'order_id'
#
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Aquí cuentas duplicados en la columna `order_id`, pero la verificación clave en esta sección es si hay filas completamente duplicadas. Considera primero comprobar duplicados de fila completa (toda la fila repetida) y luego, opcionalmente, comprobar los IDs duplicados por separado si quieres comentar las expectativas de unicidad.
#
# </div>

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
#
# Sí, hay 15 líneas duplicadas con el día de la semana y la hora de la order en común

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
orders_m_2 = df_icorders.query('order_dow == 3 and order_hour_of_day == 2')
print(orders_m_2)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# ¿Qué sugiere este resultado?
#
# Sugiere que el día miércoles a las 2 am se realizaron muchos más pedidos, por lo que las 15 líneas duplicadas del paso anterior deben tener otro valor duplicado, probablemente el order_id

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Tu interpretación de la consulta “Wednesday at 2 a.m.” está un poco desconectada de las filas duplicadas que encontraste. Considera comprobar explícitamente si las filas duplicadas están contenidas en este subconjunto de miércoles a las 2 a.m. y luego explica qué sugiere eso sobre por qué se producen duplicados en ese día/hora específicos.
#
# </div>

# %%
# Elimina los pedidos duplicados
df_icorders = df_icorders.drop_duplicates()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Después de crear `df_icorders_nodups`, asegúrate de que el análisis posterior use de forma consistente el DataFrame de pedidos limpio. De lo contrario, los resultados posteriores podrían seguir incluyendo los registros de pedidos duplicados que pretendías eliminar.
#
# </div>

# %%
# Vuelve a verificar si hay filas duplicadas
print(df_icorders[df_icorders.duplicated()])
print()
print(f'Hay {df_icorders.duplicated().sum()} duplicados en el nuevo df')
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []
#
# Hay 0 duplicados en el nuevo df

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
sum_dups = df_icorders["order_id"].duplicated().sum()
print(f"Hay {sum_dups} IDs duplicados de pedidos")
# Out:
# Hay 0 IDs duplicados de pedidos

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
# Encontré varios duplicados en la columna "order_id" que fueron hechos el mismo día a la misma hora, probablemente un error de la plataforma de pedidos. Los eliminé de la base de datos.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Este resumen es un poco engañoso: los duplicados que mostraste son *filas* duplicadas (registros de pedidos duplicados), no simplemente “duplicados en `order_id`”. Considera describirlos como filas de pedidos idénticas y, luego, señalar que los valores duplicados de `order_id` desaparecen una vez que se eliminan esas filas repetidas.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Hiciste una correcta eliminación de los duplicados.

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
dups_products = df_products.duplicated().sum()
print(f"Hay {dups_products} filas totalmente duplicadas en el df Products")
df_dups_p = df_products[df_products.duplicated()]
print(df_dups_p)
# Out:
# Hay 0 filas totalmente duplicadas en el df Products
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
# Revisa únicamente si hay ID de productos duplicados
dups_p_id = df_products["product_id"].duplicated().sum()
print(f"Hay {dups_p_id} IDs de productos duplicados")
# Out:
# Hay 0 IDs de productos duplicados

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
df_products["product_name"] = df_products["product_name"].str.lower()
dups_p_name = df_products["product_name"].duplicated().sum()
print(f"Hay {dups_p_name} nombres duplicados de productos")
df_pname_dups = df_products[df_products["product_name"].duplicated()]
print()
print(df_pname_dups["product_name"].str.upper())
# Out:
# Hay 1361 nombres duplicados de productos
#
# 71                                                   NaN
# 109                                                  NaN
# 296                                                  NaN
# 416                                                  NaN
# 436                                                  NaN
#                               ...
# 49689                      HIGH PERFORMANCE ENERGY DRINK
# 49690                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692                             SPRING WATER BODY WASH
# 49693                            BURRITO- STEAK & CHEESE
# Name: product_name, Length: 1361, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# En tu comprobación de “duplicate product names”, mencionas comparar nombres en mayúsculas, pero el cálculo de `duplicated()` sigue realizándose sobre los valores originales de `product_name`. Si quieres detectar duplicados que solo difieren por el uso de mayúsculas/minúsculas, calcula los duplicados sobre una versión normalizada (p. ej., convertida a mayúsculas y sin espacios) y luego inspecciona los resultados.
#
# </div>

# %%
# Revisa si hay nombres duplicados de productos no faltantes
productos_con_nombre = df_products[df_products['product_name'].notna()]
print(f"Total de productos: {len(df_products)}")
print(f"Productos con nombre: {len(productos_con_nombre)}")

#conteo de nombres
nombres_conteo = productos_con_nombre['product_name'].value_counts()

# Filtrar nombres que aparecen más de una vez
nombres_duplicados = nombres_conteo[nombres_conteo > 1]

print(f"Nombres de productos duplicados: {len(nombres_duplicados)}")
print("\nPrimeros 10 nombres duplicados:")
print(nombres_duplicados.head(10))
# Out:
# Total de productos: 49694
# Productos con nombre: 48436
# Nombres de productos duplicados: 103
#
# Primeros 10 nombres duplicados:
# green tea with ginseng and honey                   3
# fluffly vanilla marshmallow frosting               2
# chicken in a biskit baked snack crackers           2
# hydro body sponge with hand strap                  2
# cream of tartar                                    2
# concentrace trace mineral drops                    2
# organic balsamic vinegar of modena                 2
# leave-in conditioner                               2
# organic instant oatmeal light maple brown sugar    2
# aged balsamic vinegar of modena                    2
# Name: product_name, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta celda no está comprobando “nombres de producto duplicados que no sean valores faltantes”. Actualmente manipula el conteo de valores faltantes y lo imprime, pero nunca filtra los NaNs y luego verifica duplicados entre los nombres de producto restantes. Considera: primero filtrar a nombres no nulos y luego ejecutar la comprobación de duplicados sobre ese subconjunto.
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Descubrí que todos los valores duplicados de la columna de nombre de productos son productos faltantes, por lo tanto, no podemos eliminarlos aún sin tener instrucciones claras de con qué reemplazarlos

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #1</b> <a class="tocSkip"></a>
#
# Hiciste un buen trabajo al no eliminar estos valores duplicados por nombre, ya que al tener el mismo nombre pero diferentes IDs puede tratarse de productos con diferentes ubicaciones o productos completamente diferentes nombrados de forma erronea.
#
# Excelente trabajo con la correccion de mayusculas, caracteres especiales y espacios.

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
dups_departments = df_departments.duplicated().sum()
print(f"Hay {dups_departments} filas totalmente duplicadas en el df Departments")
df_dups_d = df_departments[df_departments.duplicated()]
print(df_dups_d)
# Out:
# Hay 0 filas totalmente duplicadas en el df Departments
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %%
# Revisa únicamente si hay IDs duplicadas de departamentos
dups_did = df_departments["department_id"].duplicated().sum()
print(f"Hay {dups_did} IDs duplicados de departamentos")
# Out:
# Hay 0 IDs duplicados de departamentos

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Descubrí que no hay ningún departamento ni ID de departamento duplicado en el dataframe

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
dups_aisles = df_aisles.duplicated().sum()
print(f"Hay {dups_aisles} filas totalmente duplicadas en el df de Pasillos")
df_dups_a = df_aisles[df_aisles.duplicated()]
print(df_dups_a)
# Out:
# Hay 0 filas totalmente duplicadas en el df de Pasillos
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Tu mensaje de salida usa la variable/nombre incorrecto (hace referencia a *departments* en lugar de *aisles*), lo que vuelve el resultado engañoso incluso si el valor numérico resulta ser 0. Considera corregir el f-string y la variable para que informe claramente filas/IDs duplicados de *aisle*.
#
# </div>

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
dups_aid = df_aisles["aisle_id"].duplicated().sum()
print(f"Hay {dups_did} IDs duplicados de departamentos")
# Out:
# Hay 0 IDs duplicados de departamentos

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Descubrí que no hay ninguna fila ni ID duplicado en el dataframe de pasillos

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
dups_order = df_order.duplicated().sum()
print(f"Hay {dups_order} filas totalmente duplicadas en el df de Órdenes")
df_dups_o = df_order[df_order.duplicated()]
print(df_dups_o)
# Out:
# Hay 0 filas totalmente duplicadas en el df de Órdenes
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
dups_oid = df_order["order_id"].duplicated().sum()
dups_opid = df_order["product_id"].duplicated().sum()
print(f"Hay {dups_oid} IDs de órdenes duplicados en el df de Órdenes de Productos")
print()
print(f"Hay {dups_opid} IDs de productos en el df de Órdenes de Productos")
# Out:
# Hay 4094961 IDs de órdenes duplicados en el df de Órdenes de Productos
#
# Hay 4499434 IDs de productos en el df de Órdenes de Productos

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Descubrí filas con el "order_id" duplicado (el cual es un valor único para cada orden/pedido), pero esto significa que se compraron varios productos en una sola órden, por lo cual es válido que este se repita varias veces.
# Algo similar pasa con el "product_id", el mismo producto puede comprarse varias veces en varias órdenes diferentes, o incluso en la misma órden, entonces es válido que se repita.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Excelente trabajo con las tablas `departments`, `aisles` y `order_products`.

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
products_na = df_products[df_products["product_name"].isna()]
print(products_na)
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se hallaron 1258 productos con nombres no definidos

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
cuenta = len(products_na.query("aisle_id == 100"))
if cuenta == len(products_na["product_id"]):
    print("Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100")
# Out:
# Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Sí, todos los valores ausentes están relacionados con el passido 100

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
cuenta = len(products_na.query("department_id == 21"))
if cuenta == len(products_na["product_id"]):
    print("Todos los nombres de productos ausentes están relacionados con el departamento con ID 21")
# Out:
# Todos los nombres de productos ausentes están relacionados con el departamento con ID 21

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Todos los nombres de productos ausentes están relacionados con el departamento con ID 21

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
# Revisar qué pasillo es el ID 100
pasillo_100 = df_aisles.query("aisle_id == 100")
print("Información del pasillo ID 100:")
print(pasillo_100)
print()

# Revisar qué departamento es el ID 21
departamento_21 = df_departments.query("department_id == 21")
print("Información del departamento ID 21:")
print(departamento_21)
# Out:
# Información del pasillo ID 100:
#     aisle_id    aisle
# 99       100  missing
#
# Información del departamento ID 21:
#     department_id department
# 20             21    missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Los datos del pasillo 100 y el departameto 21 están "missing", esto puede significar una pérdida de información durante la creación del archivo, le traspaso de la información, la creación de la base de datos, etc

# %%
# Completa los nombres de productos ausentes con 'Unknown'
df_products["product_name"].fillna("Unknown", inplace = True)
print(df_products.query("product_name == 'Unknown'"))
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38      Unknown       100             21
# 71             72      Unknown       100             21
# 109           110      Unknown       100             21
# 296           297      Unknown       100             21
# 416           417      Unknown       100             21
# ...           ...          ...       ...            ...
# 49552       49553      Unknown       100             21
# 49574       49575      Unknown       100             21
# 49640       49641      Unknown       100             21
# 49663       49664      Unknown       100             21
# 49668       49669      Unknown       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Ten cuidado con `df_products.fillna('Unknown', inplace=True)` porque rellena *todos* los valores faltantes en la tabla de productos, no solo `product_name`. Aunque otras columnas actualmente no tengan valores faltantes, es más seguro y más claro rellenar solo la columna `product_name` para que no sobrescribas accidentalmente otros datos faltantes.
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Reemplacé los datos ausentes con el string "Unknown" para poder trabajar con los datos de mejor manera en los siguientes pasos

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Muy bien! Hiciste un buen trabajo al ahondar en los datos ausentes y su correspondencia con las tablas de pasillos y departamentos. Hiciste el correcto reemplazo de valores ausentes.

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
print(df_icorders.isna().sum())
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
verificar = df_icorders.query("days_since_prior_order == None")["order_number"]
print(verificar)
print(f"No hay más valores ausentes aparte del primer pedido del cliente:")
print()
df_icorders["days_since_prior_order"].fillna(1, inplace=True)
print(f"Info de la nueva base de datos llenando los datos ausentes: \n")
df_icorders.info()
print(df_icorders["days_since_prior_order"])
# Out:
# Series([], Name: order_number, dtype: int64)
# No hay más valores ausentes aparte del primer pedido del cliente:
#
# Info de la nueva base de datos llenando los datos ausentes:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478952 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478952 non-null  int64
#  1   user_id                 478952 non-null  int64
#  2   order_number            478952 non-null  int64
#  3   order_dow               478952 non-null  int64
#  4   order_hour_of_day       478952 non-null  int64
#  5   days_since_prior_order  478952 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 25.6 MB
# 0         30.0
# 1          9.0
# 2          2.0
# 3         10.0
# 4         17.0
#           ...
# 478962     7.0
# 478963     6.0
# 478964     6.0
# 478965     8.0
# 478966    15.0
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Dos cosas que abordar aquí: (1) la pregunta te pide verificar si los valores faltantes de `days_since_prior_order` ocurren solo en los primeros pedidos de los clientes, así que considera filtrar realmente las filas con `days_since_prior_order` faltante y comprobar su `order_number`. (2) Rellenar `days_since_prior_order` con la cadena "Unknown" cambia la columna a dtype `object` y hace que el análisis numérico posterior sea más difícil; por lo general es mejor mantenerla numérica y tratar NaN como “primer pedido” (o manejar los primeros pedidos por separado) mientras explicas tu elección.
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Encontré datos ausentes en la columna "days_since_prior_order, los cambié por "1", reemplazando los valores vacíos por el primer pedido

# %% [raw]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Excelente. Encontraste que si se encuentran ordenes que sean el primer pedido del cliente, es normal que no tengamos información sobre cuántos días han pasado desde su último pedido (days_since_prior_order), por lo cual son filas que se mantienen sin cambios.

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
print(df_order.isna().sum())
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
min_ = df_order["add_to_cart_order"].min()
max_ = df_order["add_to_cart_order"].max()
print(f"Valor mínimo: {min_}. Valor máximo: {max_}")
# Out:
# Valor mínimo: 1.0. Valor máximo: 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Valor mínimo: 1.0. Valor máximo: 64.0

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
order_na = df_order[df_order["add_to_cart_order"].isna()]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Tu análisis de los valores faltantes de `add_to_cart_order` está incompleto: descubriste que los pedidos afectados pueden tener tan solo 1 artículo, lo cual entra en conflicto con la hipótesis común de que los valores faltantes aparecen solo cuando un pedido tiene > 64 artículos. Considera probar explícitamente si el recuento de artículos de cada pedido afectado supera 64 y luego interpretar el resultado en función de lo que observes.
#
# </div>

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
order_na_grouped = order_na.groupby("order_id")
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
productos_por_pedido = order_na_grouped.size()
print("Número de productos por pedido:")
print(productos_por_pedido)
print()
min_productos = productos_por_pedido.min()
print(f"Valor mínimo de productos en un pedido: {min_productos}")
# Out:
# Número de productos por pedido:
# order_id
# 9310        1
# 61355      63
# 102236     31
# 129627      5
# 165801      6
#            ..
# 2999801     6
# 3125735    22
# 3308010    51
# 3347453     7
# 3383594     5
# Length: 70, dtype: int64
#
# Valor mínimo de productos en un pedido: 1

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos? No, tienen diferente valores, yendo desde 64 hasta 1

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
df_order["add_to_cart_order"] = df_order["add_to_cart_order"].fillna(999).astype("int")

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Llené los valores ausentes con 999 y transformé todos los datos de la columna a tipo entero

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Buen trabajo, encontraste que al parecer solo se detecta los primeros 64 productos que se agregan al carrito y si se agregan más productos, deja de registrar el orden correctamente y esos valores aparecen como ausentes.

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos
#
# El procesamiento de datos es un paso muy importante para asegurar que la información es útil y correcta. Los dato duplicados y ausentes son un problema que se puede resolver fácilmente con un poco de esfuerzo y entedimeinto del funcionamiento de las bases de datos y cómo trabajarlas

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
x = df_icorders["order_hour_of_day"]
print("=== Verificación de order_hour_of_day ===")
min_hour = x.min()
max_hour = x.max()
print(f"Valor mínimo: {min_hour}")
print(f"Valor máximo: {max_hour}")
# Verificar si todos los valores están en el rango esperado:
valores_fuera_de_rango_hour = df_icorders[(x<0) | (x>23)]
print(f"Valores fuera del rango (0-23 horas): {len(valores_fuera_de_rango_hour)}")
# Out:
# === Verificación de order_hour_of_day ===
# Valor mínimo: 0
# Valor máximo: 23
# Valores fuera del rango (0-23 horas): 0

# %%
y = df_icorders["order_dow"]
print("=== Verificación de order_dow ===")
min_dow = y.min()
max_dow = y.max()
print(f"Valor mínimo: {min_dow}")
print(f"Valor máximo: {max_dow}")
# Verificar si todos los valores están en el rango esperado:
valores_fuera_de_rango_dow = df_icorders[(y<0) | (y>6)]
print(f"Valores fuera del rango (0-6): {len(valores_fuera_de_rango_dow)}")
# Out:
# === Verificación de order_dow ===
# Valor mínimo: 0
# Valor máximo: 6
# Valores fuera del rango (0-6): 0

# %% [markdown]
# Escribe aquí tus conclusiones
#
# NO se econtraron valores fuera de los rangos establecidos

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo al verificar que tanto `order_hour_of_day` como `order_dow` estén dentro de los rangos esperados y al resumir la comprobación de forma clara.
#
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
from matplotlib import pyplot as plt
numero_de_ordenes = df_icorders.groupby("order_hour_of_day")["user_id"].nunique()
numero_de_ordenes.plot(
    x="order_hour_of_day",
    y="user_id",
    xlabel="Hora del día",
    ylabel="Cantidad de Usuarios",
    kind = "bar",
    title = "Cantidad de Órdenes Diarias", 
    rot = 0)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta pregunta pide el número de *personas* que realizan pedidos por hora, pero tu código cuenta pedidos (`order_id`). Eso sobrecontará a los usuarios que hacen varios pedidos. Considera agrupar por hora y contar `user_id` únicos (p. ej., `nunique`) para que coincida con lo que pide la pregunta.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se puede ver una alta actividad en el rango 9 - 17, que concuenrdan con las horas de actividad más comunes de las personas en el día a día

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
columnas = ["Domingo", "Lunes", "Martes", "Miércoles", "Jueves", "Viernes", "Sábado"]
conteo = df_icorders.groupby("order_dow")["order_id"].count()
print(conteo)
ordenes_semanales = df_icorders.groupby("order_dow")["order_id"].count().set_axis(columnas, axis = 0)
print(ordenes_semanales)
ordenes_semanales.plot(
    x="order_dow",
    y="order_id",
    xlabel="Día de la semana",
    ylabel="Número de pedidos",
    kind = "bar",
    color = "gray",
    title = "Órdenes Semanales", 
    rot = 0
    )
plt.show()
# Out:
# order_dow
# 0    84090
# 1    82185
# 2    65833
# 3    60897
# 4    59810
# 5    63488
# 6    62649
# Name: order_id, dtype: int64
# Domingo      84090
# Lunes        82185
# Martes       65833
# Miércoles    60897
# Jueves       59810
# Viernes      63488
# Sábado       62649
# Name: order_id, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Tu gráfico va por buen camino, pero reemplazar manualmente `order_dow` por nombres de días de la semana puede ser engañoso a menos que confirmes explícitamente que el mapeo coincide con la codificación del dataset (0=Sunday … 6=Saturday). Considera añadir una verificación rápida (p. ej., mostrar los conteos por `order_dow` antes de reasignar las etiquetas) para que quede claramente justificado el etiquetado.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se puede observar un patrón de compra que aumneta los días Domingo y Lunes, durante el resto de días los hábitos de compra son estables. Esta información nos puede ayudar a crear campañas de marketing enfocadas en las horas y días con mayor afluencia de usuarios

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
dias_entre_ordenes = df_icorders.groupby("days_since_prior_order")["order_id"].count().dropna()
dias_entre_ordenes.plot(
    x= "days_since_prior_order",
    y= "order_id",
    xlabel= "Días desde último pedido",
    ylabel= "Cantida de usuarios",
    kind = "bar",
    color = "purple",
    title = "Tiempo de espera para realizar otra compra", 
    rot = 0, 
    figsize = [18,8]
    )
print(f"Tiempo de espera máximo: {df_icorders['days_since_prior_order'].max()}")
print(f"Tiempo de espera mínimo: {df_icorders['days_since_prior_order'].min()}")
plt.show()
# Out:
# Tiempo de espera máximo: 30.0
# Tiempo de espera mínimo: 0.0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Este gráfico excluye los primeros pedidos porque `days_since_prior_order` tiene NaNs, por lo que la visualización y la interpretación omiten de forma silenciosa una categoría importante. Además, la tarea te pide comentar los tiempos mínimos y máximos de espera—considera calcular/reportar esos valores explícitamente (y aclarar cómo se manejan los NaNs/primeros pedidos) junto con el gráfico.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se observa que una gran cantidad de usuarios esperan 30 días para realizar su próxima compra. Pero el tiempo de espera en general es menor, concentrando la mayor cantidad de usuarios en un timpo de re compra de entre 0 a 9 días.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Excelente! Los gráficos que presentas muestran claramente cada una de las mediciones solicitadas, tienen una buena presentación de ejes y etiquetado correcto. Tus conclusiones son muy buenas, respecto a las horas y los días en que los usuarios hacen mayores compras.

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
#dfs de cada día
miercoles = df_icorders.query("order_dow == 3")
sabado = df_icorders.query("order_dow == 6")
#agrupar dfs y contar
ordenes_miercoles = miercoles.groupby("order_hour_of_day")["order_id"].count()
ordenes_sabado = sabado.groupby("order_hour_of_day")["order_id"].count()
#graficar
ordenes_miercoles.plot(
    x="order_hour_of_day",
    y="order_id",
    xlabel="Hora del día",
    ylabel="Número de pedidos",
    kind = "bar",
    title = "Cantidad de Órdenes Diarias (Miércoles y Sábado)", 
    rot = 0,
    color = "orange",
    legend = True,
    label = "Miércoles")

ordenes_sabado.plot(
    x="order_hour_of_day",
    y="order_id",
    xlabel="Hora del día",
    ylabel="Número de pedidos",
    kind = "bar", 
    rot = 0,
    color = "blue",
    alpha = 0.5,
     legend = True,
    label = "Sábado")
plt.show()
print()
ordenes_miercoles.plot(kind="hist", alpha=0.5, legend = True, label = "Miércoles", title = "Cantidad de Órdenes Diarias (Miércoles y Sábado)")
ordenes_sabado.plot(kind="hist", alpha=0.5,  legend = True, label = "Sábado")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La tarea solicita específicamente histogramas de `order_hour_of_day` para miércoles vs. sábado en la misma figura para comparar las formas de las distribuciones. Tus gráficos de barras superpuestos de conteos por hora son informativos, pero considera rehacerlo usando histogramas, como se pide, para que la comparación se ajuste a las instrucciones del trabajo.
# ![image.png](attachment:e3181ae3-64d6-456f-a317-4495f27c0306.png)
# </div>

# %% [markdown]
# Se observa en general una mayor cantidad de órdenes los días sábados que los miércoles, en especial entre las 10:00 y las 17:00, teniendo el pico entre las 13:00 y las 14:00. Las dos distribuciones tienen una forma similar.
# ![image.png](attachment:1933acb3-0d77-4acb-9ed3-c586f9b67fb1.png)

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
numero_de_ordenes = df_icorders.groupby("order_number")["user_id"].count()
numero_de_ordenes.plot(
    x = "order_number",
    y = "user_id", 
    xlabel = "Cantidad de Órdenes",
    ylabel = "Cantidad de Usuarios",
    color = "purple",
    title = "Cantidad de órdenes que hacen los usuarios",
    kind = "bar", 
    rot = 0, 
    figsize = [30, 8]
)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esto aún no responde a “cuántos clientes hicieron 1 pedido, 2 pedidos, 3 pedidos, …”. Agrupar por `order_number` cuenta los pedidos por posición en la secuencia, no los pedidos por cliente. Considera calcular primero el número total de pedidos de cada usuario (agrupar por `user_id`, contar `order_id` distintos), y luego graficar la distribución de esos totales por usuario.
#
# </div>

# %% [markdown]
# Los productos más comprados sulen ser productos orgánicos, parece que los clientes prefiern este tipo de productos para sus hogares. Tmabién se observa una grandísima cantida dde órdenes únicas o peuqeñas, menos de 20 productos.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# El texto de conclusión aquí no coincide con la tarea B2 (habla de productos populares y del tamaño del pedido). Considera reemplazarlo por una breve interpretación de la distribución de *orders-per-customer* (p. ej., dónde alcanza su pico, qué tan rápido disminuye y si hay una cola larga de clientes frecuentes).
#
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
top_20 = df_order.groupby("product_id")["order_id"].count().sort_values(ascending = False).head(20)
#transformar top_20 en un df
top_20_df = pd.DataFrame({"product_id":top_20.index, "frecuencia":top_20.values})
top_20_nombres = top_20_df.merge(df_products[["product_id", "product_name"]], on = "product_id", how = "left")
print(top_20_nombres)
# Out:
#     product_id  frecuencia              product_name
# 0        24852       66050                    banana
# 1        13176       53297    bag of organic bananas
# 2        21137       37039      organic strawberries
# 3        21903       33971      organic baby spinach
# 4        47209       29773      organic hass avocado
# 5        47766       24689           organic avocado
# 6        47626       21495               large lemon
# 7        16797       20018              strawberries
# 8        26209       19690                     limes
# 9        27845       19600        organic whole milk
# 10       27966       19197       organic raspberries
# 11       22935       15898      organic yellow onion
# 12       24964       15292            organic garlic
# 13       45007       14584          organic zucchini
# 14       39275       13879       organic blueberries
# 15       49683       13675            cucumber kirby
# 16       28204       12544        organic fuji apple
# ...

# %% [markdown]
# Los productos más comprados sulen ser productos orgánicos, parece que los clientes prefiern este tipo de productos para sus hogares. También se observa una grandísima cantida dde órdenes únicas o peuqeñas, menos de 20 productos.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Este texto de conclusiones está duplicado y no es específico del resultado de top-20-products. Considera mantener una única conclusión breve para la tabla de top-20 que haga referencia a lo que encontraste (p. ej., qué productos dominan y qué sugieren las frecuencias sobre las preferencias de los clientes).
#
# </div>

# %% [markdown]
# Los productos más comprados sulen ser productos orgánicos, parece que los clientes prefiern este tipo de productos para sus hogares. Tmabién se observa una grandísima cantida dde órdenes únicas o peuqeñas, menos de 20 productos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# Vamos por partes:
# - En la parte B1 hiciste correctamente la comparacion entre los dias miercoles y sabado, reconociendo como los picos de un dia son mas bajos en el otro. Muy buen uso del histograma combinando ambos datos con diferenciador por color.
# - En el inciso B2 hiciste un buen uso del histograma, concluyendo correctamente sobre los habitos de los usuarios.
# - En el inciso B3 hiciste un excelente uso de `merge` para obtener el top de productos con sus identificadores y nombres.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
#cantidad de productos por órden
prod_por_pedido = df_order.groupby("order_id")["product_id"].count()
#promedio de prodcutos por órden
prod_prom = prod_por_pedido.mean().astype("int")
print(f"Los usuarios compran en normalmente (en promedio) {prod_prom} productos en un pedido \n")
prod_por_pedido.plot(kind = "hist", title = "Artículos / Persona", color = "pink")
plt.show()
# Out:
# Los usuarios compran en normalmente (en promedio) 10 productos en un pedido

# %% [markdown]
# Una gran cantidad de usuarios normalmente hace pedidos de 10 productos, lo que refuerza nuestra conclusión anterior sobre los usuarios haciendo compras únicas y pequeñas (menores a 20 artículos)

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
re_ordered_art = df_order.query("reordered == 1")
top_20_art = re_ordered_art.groupby("product_id")["order_id"].count().sort_values(ascending = False).head(20)
top_20_art_df = pd.DataFrame({"product_id":top_20_art.index, "frecuencia":top_20_art.values})
top_20_art_nombres = top_20_art_df.merge(df_products[["product_id", "product_name"]], on = "product_id", how = "left")
print(top_20_art_nombres)
# Out:
#     product_id  frecuencia              product_name
# 0        24852       55763                    banana
# 1        13176       44450    bag of organic bananas
# 2        21137       28639      organic strawberries
# 3        21903       26233      organic baby spinach
# 4        47209       23629      organic hass avocado
# 5        47766       18743           organic avocado
# 6        27845       16251        organic whole milk
# 7        47626       15044               large lemon
# 8        27966       14748       organic raspberries
# 9        16797       13945              strawberries
# 10       26209       13327                     limes
# 11       22935       11145      organic yellow onion
# 12       24964       10411            organic garlic
# 13       45007       10076          organic zucchini
# 14       49683        9538            cucumber kirby
# 15       28204        8989        organic fuji apple
# 16        8277        8836  apple honeycrisp organic
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Muy buen trabajo en general en este bloque: calculaste items-per-order y visualizaste la distribución, y además generaste correctamente el top 20 de los productos reordenados con mayor frecuencia, incluyendo tanto los IDs como los nombres. Los resultados son fáciles de seguir y respaldan tu interpretación.
#
# </div>

# %% [markdown]
# Las bananass deben ser un product bastante popular, al igual que los productos orgnánicos, porque aparte de ser los productos más populares, también son los productos que se vuleven a ordenar con mayor frecuencia

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
#Crear df con total de compras y de recompras
proporcion_recompra = df_order.groupby("product_id").agg({"reordered":["count", "sum"]})
#Cambiar nombre de columnas
proporcion_recompra.columns = ["Total Compras", "Recompras"]
#Calcular nueva columna de proporción de recompra
proporcion_recompra["Proporción de Recompra (Productos)"] = (proporcion_recompra["Recompras"]/proporcion_recompra["Total Compras"]).round(3)
#Combinar para mostrar nombre de productos
proporcion_recompra_nombres = proporcion_recompra.merge(df_products[["product_id", "product_name"]], on = "product_id", how = "left").set_index("product_id").sort_values("Proporción de Recompra (Productos)", ascending = False)
print(proporcion_recompra_nombres.sample(10))
# Out:
#             Total Compras  Recompras  Proporción de Recompra (Productos)  \
# product_id
# 32212                   9          5                               0.556
# 39185                  55         38                               0.691
# 14251                   5          1                               0.200
# 6476                    3          2                               0.667
# 19042                   2          1                               0.500
# 7101                    6          2                               0.333
# 1240                  393        258                               0.656
# 6410                   53         17                               0.321
# 43529                   8          3                               0.375
# 40186                  48         23                               0.479
#
#                                              product_name
# product_id
# 32212                                   lactose free milk
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Para esta tarea, sería útil presentar una tabla final limpia que incluya claramente `product_id`, `product_name` y la proporción de recompra (reorder proportion) como columnas explícitas (no solo como un índice). Además, imprimir una muestra aleatoria de 10 filas no demuestra los resultados solicitados por producto—considera mostrar el head (y mencionar el tamaño de la tabla) o, de otro modo, presentar la salida calculada de manera más directa.
#
# </div>

# %% [markdown]
# Un coeficiente de recompra alto no siempre significa que el producto es popular o se compra muchas veces, puede indicar que solo se ha comprado dos veces en diferentes órdenes, así que es importante analizar el número de compras y recompras

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Este párrafo es una advertencia útil, pero no resume lo que observaste a partir de tus proporciones de reorden (reorder) por producto calculadas. Considera añadir una breve interpretación basada en tus resultados (por ejemplo, si las proporciones muy altas suelen darse entre productos de bajo volumen, y cómo se ven las proporciones típicas a lo largo de los productos).
#
# </div>

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
#Crear df de ordenes con user_id
clientes_productos = df_order.merge(df_icorders[["order_id", "user_id"]], on = "order_id", how = "left")
#crear df con total de compras y recompras
clientes_productos_prop = clientes_productos.groupby("user_id").agg({"reordered":["count", "sum"]})
#cambiar nombres de columnas
clientes_productos_prop.columns = ["Total Compras", "Re-Compras"]
#agregar columna con proporciones
clientes_productos_prop["Proporción de Recompra (Usuarios)"] = (clientes_productos_prop["Re-Compras"]/clientes_productos_prop["Total Compras"]).round(3)
print(clientes_productos_prop.head(10))
# Out:
#          Total Compras  Re-Compras  Proporción de Recompra (Usuarios)
# user_id
# 2                   26           1                              0.038
# 4                    2           0                              0.000
# 5                   12           8                              0.667
# 6                    4           0                              0.000
# 7                   14          13                              0.929
# 11                  15           3                              0.200
# 12                  12           3                              0.250
# 13                  23          13                              0.565
# 14                  61          22                              0.361
# 15                  13           7                              0.538

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La proporción de reordenamiento por usuario se está calculando incorrectamente debido a la precedencia de operadores: estás redondeando solo el denominador antes de dividir, en lugar de redondear la razón final. Considera recalcular primero la razón y luego redondear la proporción resultante para que los valores sean precisos.
#
# </div>

# %% [markdown]
# el rango de proporciones va desde 0% hasta cerca del 100%, la variedad de los resultdos podría indicar usuarios muy nuevos versus usuarios antiguos. La leatldad de los clientes está relacionada con un patrón de compra más alto, colciendo a comprar con mayor frecuencia y mayor cantidad de productos.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# En esta sección falta la conclusión escrita obligatoria que interprete las proporciones de recompra por cliente. Considera añadir un breve resumen de lo que implican los resultados (p. ej., proporciones típicas, cualquier valor extremo y lo que eso indica sobre el comportamiento de recompra de los clientes).
#
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Después de generar la tabla de los “top 20 productos añadidos primero”, la consigna también espera una breve interpretación escrita del resultado. Considera añadir una conclusión breve sobre lo que sugieren estos artículos añadidos primero (p. ej., productos básicos habituales, esenciales comprados con frecuencia, etc.), y no solo una observación sobre un único producto.
#
# </div>

# %%
primeros_productos = df_order.query("add_to_cart_order == 1")
top_20 = primeros_productos.groupby("product_id")["order_id"].count().sort_values(ascending = False).head(20)
top_20_df = pd.DataFrame({"product_id":top_20.index, "frecuencia":top_20.values})
top_20_df_names = top_20_df.merge(df_products[["product_id", "product_name"]], on = "product_id", how = "left")
print(f"El top 20 de principales artículos que las personas ponen primero en sus carritos es: \n{top_20_df_names}")
# Out:
# El top 20 de principales artículos que las personas ponen primero en sus carritos es:
#     product_id  frecuencia                 product_name
# 0        24852       15562                       banana
# 1        13176       11026       bag of organic bananas
# 2        27845        4363           organic whole milk
# 3        21137        3946         organic strawberries
# 4        47209        3390         organic hass avocado
# 5        21903        3336         organic baby spinach
# 6        47766        3044              organic avocado
# 7        19660        2336                 spring water
# 8        16797        2308                 strawberries
# 9        27966        2024          organic raspberries
# 10       44632        1914   sparkling water grapefruit
# 11       49235        1797          organic half & half
# 12       47626        1737                  large lemon
# 13         196        1733                         soda
# ...

# %% [markdown]
# Las bananas son un producto realmente popular y de altísima demanda

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora Iteración #2</b> <a class="tocSkip"></a>
#
# - Para el inciso C1, hiciste un correcto filtrado que permite observar de forma correcta como la cantidad de articulos por pedido oscila entre 7 y 10 articulos.
# - Para el inciso C2 hiciste un buen uso de `.merge` para encontrar como los productos mas reordenados.
# - En el punto C3 la tasa de repeticion por producto está correctamente calculada.
# - En el punto C4 hiciste un excelente uso de `groupby` para encontrar la tasa de repeticion por cliente.
# - En el punto C5 hiciste un excelente filtrado para encontrar los productos que las personas escogen de primero en sus carritos.
#
# Excelente trabajo!

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# El análisis de datos es un paso importante para la toma de decisiones sabias e informadas, durante este proyecot entendí la importancia de hacer las preguntas adecuadas, tener información clara y entender cómo funcionan las bases de datos. Gracias a herrmaientas como Python y sus útiles librerias puedo realizar todos estos cálculos complejos y entregar información valiosa a los clientes

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La conclusión de tu proyecto es reflexiva, pero se espera que el cierre final resuma los *hallazgos* clave de las partes A–C y las principales decisiones de preprocesamiento (valores faltantes y duplicados) de manera concisa y específica. Considera revisar la conclusión para destacar brevemente los patrones principales que descubriste (comportamiento por horas/días, manejo de mínimos/máximos del tiempo de espera, productos principales/reorders, etc.) y cómo tus decisiones de limpieza afectaron el análisis.
#
# </div>
